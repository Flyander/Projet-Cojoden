# %%
import pandas as pd

# %%
df = pd.read_csv("data/base-joconde.csv", sep=";")
# Out:
# C:\Users\utilisateur\anaconda3\envs\module\lib\site-packages\IPython\core\interactiveshell.py:3185: DtypeWarning: Columns (3,30,41,42,49,61,62,63,64,67) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.columns
# Out:
# Index(['ID-notice', 'POP_CONTIENT_GEOLOCALISATION', 'POP_COORDONNEES',
#        'Ancien dépôt', 'Appellation', 'APTN', 'ATTR', 'Auteur', 'BASE', 'BIBL',
#        'COMM', 'CONTIENT_IMAGE', 'Source et date de la notice',
#        'Date d'acquisition', 'Date de dépôt', 'Découverte', 'Dénomination',
#        'Dépôt', 'DESC', 'Dimensions', 'Date de mise à jour', 'Date d'import',
#        'Domaine', 'DPT', 'DREP', 'Ecole', 'Epoque', 'ETAT', 'EXPO', 'GENE',
#        'Géographie historique', 'HIST', 'HISTORIQUE', 'IMAGE', 'INSC',
#        'Numéro de l'objet', 'Label Musée de France', 'LARC',
#        'Lieu de création', 'Lieu de conservation', 'LOCA2', 'MANQUANT',
#        'MANQUANT_COM', 'Millésime', 'Millésime d'utilisation', 'MSGCOM',
#        'Identifiant Museofile', 'NOMOFF', 'NSDA', 'Onomastique',
#        'Précisions sur l'auteur', 'PDEC', 'Période de l'original copié',
#        'Période de création', 'Période d'utilisation', 'PHOT', 'PINS',
# ...

# %%
df.head()
# Out:
#      ID-notice POP_CONTIENT_GEOLOCALISATION     POP_COORDONNEES Ancien dépôt  \
# 0  M0435002007                          oui   49.112285,2.21638          NaN
# 1  M0435001924                          oui   49.112285,2.21638          NaN
# 2  M0435002028                          oui   49.112285,2.21638          NaN
# 3  08120020599                          oui  49.890413,2.295968          NaN
# 4  08120020608                          oui  49.890413,2.295968          NaN
#
#   Appellation                                               APTN ATTR  \
# 0         NaN                            De Michel Bloit en 1993  NaN
# 1         NaN                              Fonds ancien du Musée  NaN
# 2         NaN  Don de l'Association des Amis du musée ; Maiso...  NaN
# 3         NaN                   Collection privée, Duthoit, 1912  NaN
# 4         NaN                   Collection privée, Duthoit, 1912  NaN
#
#                              Auteur  \
# 0           LE GULUCHE Joseph Marie
# ...
